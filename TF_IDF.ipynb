# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A04B1/AI-ASSIGNMENTS/blob/master/TF_IDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
A="New Delhi: PM Narendra Modi is likely to address the nation again to announce his decision on whether the coronaviruslockdown will end on Tuesday. Before the decision, he will meet with Chief Ministers via video conference today.In a video meeting with leaders of all parties on Wednesday, PM Modi had said by all accounts the lifting of the lockdownis not possible"
"The priority of the government is to save each and every life. The situation in the country is akin to a 'social emergency', it has necessitated tough decisions and we must continue to remain vigilant,said the PM, according to political leaders who participated in the interaction."
B="PM Modi's decision to order the three-week lockdown has helped slow the infection rate, foreign 	ministry additionalsecretary Vikas Swarup has said, even though it has impacted the economy and thousands of poor workers. Millions of people have lost their jobs, largely those who work on daily wages and have fled to their homes in villagesMany states have sought an extension of the 21-day nationwide lockdown announced by PM Modi on March 25, saying they will not be able to handle a surge of COVID-19 cases. Odisha yesterday became the first state to announce a lockdown till the end of this month. PM Modi expressed to have good days after lockdown,"
C="J.P. Nadda on Thursday slammed Congress chief Sonia Gandhi's criticism of the lockdown as insensitive and indecent,saying this is not the time for politics when the entire country is fighting the coronavirus. Top Congress leaders on Thursday discussed the situation arising out of the coronavirus outbreak, with party chief Sonia Gandhi criticizing the Centre for unplanned implementation of the lockdown and calling for solidarity in meeting the challenge posed by the pandemic."

# %%
bagOfWordsA = A.split(' ')
bagOfWordsB = B.split(' ')
bagOfWordsC = C.split(' ')

# %%
print(bagOfWordsA) 
print(bagOfWordsB) 
print(bagOfWordsC)
# Out:
# ['New', 'Delhi:', 'PM', 'Narendra', 'Modi', 'is', 'likely', 'to', 'address', 'the', 'nation', 'again', 'to', 'announce', 'his', 'decision', 'on', 'whether', 'the', 'coronaviruslockdown', 'will', 'end', 'on', 'Tuesday.', 'Before', 'the', 'decision,', 'he', 'will', 'meet', 'with', 'Chief', 'Ministers', 'via', 'video', 'conference', 'today.In', 'a', 'video', 'meeting', 'with', 'leaders', 'of', 'all', 'parties', 'on', 'Wednesday,', 'PM', 'Modi', 'had', 'said', 'by', 'all', 'accounts', 'the', 'lifting', 'of', 'the', 'lockdownis', 'not', 'possible']
# ['PM', "Modi's", 'decision', 'to', 'order', 'the', 'three-week', 'lockdown', 'has', 'helped', 'slow', 'the', 'infection', 'rate,', 'foreign', '\tministry', 'additionalsecretary', 'Vikas', 'Swarup', 'has', 'said,', 'even', 'though', 'it', 'has', 'impacted', 'the', 'economy', 'and', 'thousands', 'of', 'poor', 'workers.', 'Millions', 'of', 'people', 'have', 'lost', 'their', 'jobs,', 'largely', 'those', 'who', 'work', 'on', 'daily', 'wages', 'and', 'have', 'fled', 'to', 'their', 'homes', 'in', 'villagesMany', 'states', 'have', 'sought', 'an', 'extension', 'of', 'the', '21-day', 'nationwide', 'lockdown', 'announced', 'by', 'PM', 'Modi', 'on', 'March', '25,', 'saying', 'they', 'will', 'not', 'be', 'able', 'to', 'handle', 'a', 'surge', 'of', 'COVID-19', 'cases.', 'Odisha', 'yesterday', 'became', 'the', 'first', 'state', 'to', 'announce', 'a', 'lockdown', 'till', 'the', 'end', 'of', 'this', 'month.', 'PM', 'Modi', 'expressed', 'to', 'have', 'good', 'days', 'after', 'lockdown,']
# ['J.P.', 'Nadda', 'on', 'Thursday', 'slammed', 'Congress', 'chief', 'Sonia', "Gandhi's", 'criticism', 'of', 'the', 'lockdown', 'as', 'insensitive', 'and', 'indecent,saying', 'this', 'is', 'not', 'the', 'time', 'for', 'politics', 'when', 'the', 'entire', 'country', 'is', 'fighting', 'the', 'coronavirus.', 'Top', 'Congress', 'leaders', 'on', 'Thursday', 'discussed', 'the', 'situation', 'arising', 'out', 'of', 'the', 'coronavirus', 'outbreak,', 'with', 'party', 'chief', 'Sonia', 'Gandhi', 'criticizing', 'the', 'Centre', 'for', 'unplanned', 'implementation', 'of', 'the', 'lockdown', 'and', 'calling', 'for', 'solidarity', 'in', 'meeting', 'the', 'challenge', 'posed', 'by', 'the', 'pandemic.']

# %%
uniqueWords = set(bagOfWordsA).union(set(bagOfWordsB))

# %%
uniqueWords=set(uniqueWords).union(set(bagOfWordsC))

# %%
uniqueWords
# Out:
# {'\tministry',
#  '21-day',
#  '25,',
#  'Before',
#  'COVID-19',
#  'Centre',
#  'Chief',
#  'Congress',
#  'Delhi:',
#  'Gandhi',
#  "Gandhi's",
#  'J.P.',
#  'March',
#  'Millions',
#  'Ministers',
#  'Modi',
#  "Modi's",
#  'Nadda',
#  'Narendra',
#  'New',
#  'Odisha',
#  'PM',
#  'Sonia',
#  'Swarup',
#  'Thursday',
#  'Top',
#  'Tuesday.',
#  'Vikas',
#  'Wednesday,',
#  'a',
#  'able',
#  'accounts',
#  'additionalsecretary',
#  'address',
#  'after',
#  'again',
#  'all',
#  'an',
#  'and',
#  'announce',
#  'announced',
#  'arising',
#  'as',
#  'be',
#  'became',
#  'by',
#  'calling',
#  'cases.',
#  'challenge',
#  'chief',
#  'conference',
#  'coronavirus',
#  'coronavirus.',
#  'coronaviruslockdown',
#  'country',
#  'criticism',
#  'criticizing',
#  'daily',
#  'days',
#  'decision',
#  'decision,',
#  'discussed',
#  'economy',
#  'end',
#  'entire',
#  'even',
#  'expressed',
#  'extension',
#  'fighting',
#  'first',
#  'fled',
#  'for',
#  'foreign',
#  'good',
#  'had',
#  'handle',
#  'has',
#  'have',
#  'he',
#  'helped',
#  'his',
#  'homes',
#  'impacted',
#  'implementation',
#  'in',
#  'indecent,saying',
#  'infection',
#  'insensitive',
#  'is',
#  'it',
#  'jobs,',
#  'largely',
#  'leaders',
#  'lifting',
#  'likely',
#  'lockdown',
#  'lockdown,',
#  'lockdownis',
#  'lost',
#  'meet',
#  'meeting',
#  'month.',
#  'nation',
#  'nationwide',
#  'not',
#  'of',
#  'on',
#  'order',
#  'out',
#  'outbreak,',
#  'pandemic.',
#  'parties',
#  'party',
#  'people',
#  'politics',
#  'poor',
#  'posed',
#  'possible',
#  'rate,',
#  'said',
#  'said,',
#  'saying',
#  'situation',
#  'slammed',
#  'slow',
#  'solidarity',
#  'sought',
#  'state',
#  'states',
#  'surge',
#  'the',
#  'their',
#  'they',
#  'this',
#  'those',
#  'though',
#  'thousands',
#  'three-week',
#  'till',
#  'time',
#  'to',
#  'today.In',
#  'unplanned',
#  'via',
#  'video',
#  'villagesMany',
#  'wages',
#  'when',
#  'whether',
#  'who',
#  'will',
#  'with',
#  'work',
#  'workers.',
#  'yesterday'}

# %%
numOfWordsA = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsA:
    numOfWordsA[word] += 1

numOfWordsB = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsB:
    numOfWordsB[word] += 1
    
numOfWordsC = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsC:
    numOfWordsA[word] += 1

# %%
print(numOfWordsA)

print(numOfWordsB )

print(numOfWordsC )
# Out:
# {'all': 2, 'those': 0, 'he': 1, 'calling': 1, 'situation': 1, 'Narendra': 1, 'Gandhi': 1, 'homes': 0, 'Tuesday.': 1, 'New': 1, 'parties': 1, 'thousands': 0, 'on': 5, 'people': 0, 'lost': 0, 'had': 1, '\tministry': 0, 'workers.': 0, 'via': 1, 'criticism': 1, 'and': 2, 'politics': 1, 'PM': 2, 'rate,': 0, 'accounts': 1, 'conference': 1, 'fighting': 1, 'Chief': 1, 'handle': 0, 'meeting': 2, 'yesterday': 0, 'possible': 1, 'Wednesday,': 1, 'became': 0, 'it': 0, 'slow': 0, 'has': 0, 'till': 0, 'expressed': 0, 'have': 0, 'COVID-19': 0, 'by': 2, 'largely': 0, 'daily': 0, 'Millions': 0, 'jobs,': 0, 'Modi': 2, 'first': 0, 'days': 0, 'extension': 0, 'wages': 0, 'pandemic.': 1, 'month.': 0, 'lockdown,': 0, 'will': 2, 'Swarup': 0, 'as': 1, 'announced': 0, 'nation': 1, 'not': 2, 'decision,': 1, 'Congress': 2, 'discussed': 1, 'coronaviruslockdown': 1, 'state': 0, 'said,': 0, 'they': 0, 'work': 0, 'villagesMany': 0, 'party': 1, 'meet': 1, 'though': 0, 'a': 1, 'foreign': 0, 'end': 1, 'his': 1, 'this': 1, 'order': 0, "Gandhi's": 1, 'is': 3, 'challenge': 1, 'coronavirus.': 1, 'states': 0, 'time': 1, 'economy': 0, 'video': 2, 'saying': 0, 'nationwide': 0, 'slammed': 1, 'the': 15, 'lockdown': 2, 'unplanned': 1, 'even': 0, 'solidarity': 1, 'entire': 1, 'for': 3, 'infection': 0, 'Delhi:': 1, 'indecent,saying': 1, 'address': 1, 'whether': 1, 'with': 3, 'three-week': 0, 'J.P.': 1, 'implementation': 1, 'decision': 1, 'outbreak,': 1, '21-day': 0, "Modi's": 0, 'surge': 0, 'who': 0, 'Vikas': 0, 'March': 0, 'cases.': 0, 'chief': 2, 'to': 2, 'when': 1, 'fled': 0, 'after': 0, 'posed': 1, 'poor': 0, 'Odisha': 0, 'of': 5, 'in': 1, 'be': 0, '
': 0.0, 'Wednesday,': 0.0, 'became': 0.0, 'it': 0.0, 'slow': 0.0, 'has': 0.0, 'till': 0.0, 'expressed': 0.0, 'have': 0.0, 'COVID-19': 0.0, 'by': 0.0, 'largely': 0.0, 'daily': 0.0, 'Millions': 0.0, 'jobs,': 0.0, 'Modi': 0.0, 'first': 0.0, 'days': 0.0, 'extension': 0.0, 'wages': 0.0, 'pandemic.': 0.0, 'month.': 0.0, 'lockdown,': 0.0, 'will': 0.0, 'Swarup': 0.0, 'as': 0.0, 'announced': 0.0, 'nation': 0.0, 'not': 0.0, 'decision,': 0.0, 'Congress': 0.0, 'discussed': 0.0, 'coronaviruslockdown': 0.0, 'state': 0.0, 'said,': 0.0, 'they': 0.0, 'work': 0.0, 'villagesMany': 0.0, 'party': 0.0, 'meet': 0.0, 'though': 0.0, 'a': 0.0, 'foreign': 0.0, 'end': 0.0, 'his': 0.0, 'this': 0.0, 'order': 0.0, "Gandhi's": 0.0, 'is': 0.0, 'challenge': 0.0, 'coronavirus.': 0.0, 'states': 0.0, 'time': 0.0, 'economy': 0.0, 'video': 0.0, 'saying': 0.0, 'nationwide': 0.0, 'slammed': 0.0, 'the': 0.0, 'lockdown': 0.0, 'unplanned': 0.0, 'even': 0.0, 'solidarity': 0.0, 'entire': 0.0, 'for': 0.0, 'infection': 0.0, 'Delhi:': 0.0, 'indecent,saying': 0.0, 'address': 0.0, 'whether': 0.0, 'with': 0.0, 'three-week': 0.0, 'J.P.': 0.0, 'implementation': 0.0, 'decision': 0.0, 'outbreak,': 0.0, '21-day': 0.0, "Modi's": 0.0, 'surge': 0.0, 'who': 0.0, 'Vikas': 0.0, 'March': 0.0, 'cases.': 0.0, 'chief': 0.0, 'to': 0.0, 'when': 0.0, 'fled': 0.0, 'after': 0.0, 'posed': 0.0, 'poor': 0.0, 'Odisha': 0.0, 'of': 0.0, 'in': 0.0, 'be': 0.0, 'Ministers': 0.0, 'lifting': 0.0, 'Nadda': 0.0, 'Sonia': 0.0, 'country': 0.0, 'out': 0.0, 'arising': 0.0, 'sought': 0.0, 'impacted': 0.0, 'announce': 0.0, 'insensitive': 0.0, 'today.In': 0.0, 'leaders': 0.0, 'said': 0.0, 'their': 0.0, 'Top': 0.0, 'additionalsecretary': 0.0, 'Thursday': 0.0, 'helped': 0.0, 'able': 0.0, 'again': 0.0, '25,': 0.0, 'Before': 0.0, 'coronavirus': 0.0, 'an': 0.0, 'Centre': 0.0, 'likely': 0.0, 'good': 0.0, 'criticizing': 0.0, 'lockdownis': 0.0}

# %%
def computeIDF(documents):
    import math
    N = len(documents)
    
    idfDict = dict.fromkeys(documents[0].keys(), 0)
    for document in documents:
        for word, val in document.items():
            if val > 0:
                idfDict[word] += 1
    
    for word, val in idfDict.items():
        idfDict[word] = math.log(N / float(val))
    return idfDict
idfs = computeIDF([numOfWordsA, numOfWordsB,numOfWordsC])
idfs
# Out:
# {'\tministry': 1.0986122886681098,
#  '21-day': 1.0986122886681098,
#  '25,': 1.0986122886681098,
#  'Before': 1.0986122886681098,
#  'COVID-19': 1.0986122886681098,
#  'Centre': 1.0986122886681098,
#  'Chief': 1.0986122886681098,
#  'Congress': 1.0986122886681098,
#  'Delhi:': 1.0986122886681098,
#  'Gandhi': 1.0986122886681098,
#  "Gandhi's": 1.0986122886681098,
#  'J.P.': 1.0986122886681098,
#  'March': 1.0986122886681098,
#  'Millions': 1.0986122886681098,
#  'Ministers': 1.0986122886681098,
#  'Modi': 0.4054651081081644,
#  "Modi's": 1.0986122886681098,
#  'Nadda': 1.0986122886681098,
#  'Narendra': 1.0986122886681098,
#  'New': 1.0986122886681098,
#  'Odisha': 1.0986122886681098,
#  'PM': 0.4054651081081644,
#  'Sonia': 1.0986122886681098,
#  'Swarup': 1.0986122886681098,
#  'Thursday': 1.0986122886681098,
#  'Top': 1.0986122886681098,
#  'Tuesday.': 1.0986122886681098,
#  'Vikas': 1.0986122886681098,
#  'Wednesday,': 1.0986122886681098,
#  'a': 0.4054651081081644,
#  'able': 1.0986122886681098,
#  'accounts': 1.0986122886681098,
#  'additionalsecretary': 1.0986122886681098,
#  'address': 1.0986122886681098,
#  'after': 1.0986122886681098,
#  'again': 1.0986122886681098,
#  'all': 1.0986122886681098,
#  'an': 1.0986122886681098,
#  'and': 0.4054651081081644,
#  'announce': 0.4054651081081644,
#  'announced': 1.0986122886681098,
#  'arising': 1.0986122886681098,
#  'as': 1.0986122886681098,
#  'be': 1.0986122886681098,
#  'became': 1.0986122886681098,
#  'by': 0.4054651081081644,
#  'calling': 1.0986122886681098,
#  'cases.': 1.0986122886681098,
#  'challenge': 1.0986122886681098,
#  'chief': 1.0986122886681098,
#  'conference': 1.0986122886681098,
#  'coronavirus': 1.0986122886681098,
#  'coronavirus.': 1.0986122886681098,
#  'coronaviruslockdown': 1.0986122886681098,
#  'country': 1.0986122886681098,
#  'criticism': 1.0986122886681098,
#  'criticizing': 1.0986122886681098,
#  'daily': 1.0986122886681098,
#  'days': 1.0986122886681098,
#  'decision': 0.4054651081081644,
#  'decision,': 1.0986122886681098,
#  'discussed': 1.0986122886681098,
#  'economy': 1.0986122886681098,
#  'end': 0.4054651081081644,
#  'entire': 1.0986122886681098,
#  'even': 1.0986122886681098,
#  'expressed': 1.0986122886681098,
#  'extension': 1.0986122886681098,
#  'fighting': 1.0986122886681098,
#  'first': 1.0986122886681098,
#  'fled': 1.0986122886681098,
#  'for': 1.0986122886681098,
#  'foreign': 1.0986122886681098,
#  'good': 1.0986122886681098,
#  'had': 1.0986122886681098,
#  'handle': 1.0986122886681098,
#  'has': 1.0986122886681098,
#  'have': 1.0986122886681098,
#  'he': 1.0986122886681098,
#  'helped': 1.0986122886681098,
#  'his': 1.0986122886681098,
#  'homes': 1.0986122886681098,
#  'impacted': 1.0986122886681098,
#  'implementation': 1.0986122886681098,
#  'in': 0.4054651081081644,
#  'indecent,saying': 1.0986122886681098,
#  'infection': 1.0986122886681098,
#  'insensitive': 1.0986122886681098,
#  'is': 1.0986122886681098,
#  'it': 1.0986122886681098,
#  'jobs,': 1.0986122886681098,
#  'largely': 1.0986122886681098,
#  'leaders': 1.0986122886681098,
#  'lifting': 1.0986122886681098,
#  'likely': 1.0986122886681098,
#  'lockdown': 0.4054651081081644,
#  'lockdown,': 1.0986122886681098,
#  'lockdownis': 1.0986122886681098,
#  'lost': 1.0986122886681098,
#  'meet': 1.0986122886681098,
#  'meeting': 1.0986122886681098,
#  'month.': 1.0986122886681098,
#  'nation': 1.0986122886681098,
#  'nationwide': 1.0986122886681098,
#  'not': 0.4054651081081644,
#  'of': 0.4054651081081644,
#  'on': 0.4054651081081644,
#  'order': 1.0986122886681098,
#  'out': 1.0986122886681098,
#  'outbreak,': 1.0986122886681098,
#  'pandemic.': 1.0986122886681098,
#  'parties': 1.0986122886681098,
#  'party': 1.0986122886681098,
#  'people': 1.0986122886681098,
#  'politics': 1.0986122886681098,
#  'poor': 1.0986122886681098,
#  'posed': 1.0986122886681098,
#  'possible': 1.0986122886681098,
#  'rate,': 1.0986122886681098,
#  'said': 1.0986122886681098,
#  'said,': 1.0986122886681098,
#  'saying': 1.0986122886681098,
#  'situation': 1.0986122886681098,
#  'slammed': 1.0986122886681098,
#  'slow': 1.0986122886681098,
#  'solidarity': 1.0986122886681098,
#  'sought': 1.0986122886681098,
#  'state': 1.0986122886681098,
#  'states': 1.0986122886681098,
#  'surge': 1.0986122886681098,
#  'the': 0.4054651081081644,
#  'their': 1.0986122886681098,
#  'they': 1.0986122886681098,
#  'this': 0.4054651081081644,
#  'those': 1.0986122886681098,
#  'though': 1.0986122886681098,
#  'thousands': 1.0986122886681098,
#  'three-week': 1.0986122886681098,
#  'till': 1.0986122886681098,
#  'time': 1.0986122886681098,
#  'to': 0.4054651081081644,
#  'today.In': 1.0986122886681098,
#  'unplanned': 1.0986122886681098,
#  'via': 1.0986122886681098,
#  'video': 1.0986122886681098,
#  'villagesMany': 1.0986122886681098,
#  'wages': 1.0986122886681098,
#  'when': 1.0986122886681098,
#  'whether': 1.0986122886681098,
#  'who': 1.0986122886681098,
#  'will': 0.4054651081081644,
#  'with': 1.0986122886681098,
#  'work': 1.0986122886681098,
#  'workers.': 1.0986122886681098,
#  'yesterday': 1.0986122886681098}

# %%
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform([A,B,C])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()
denselist = dense.tolist()
df = pd.DataFrame(denselist, columns=feature_names)
df
# Out:
#          19        21        25  ...      work   workers  yesterday
# 0  0.000000  0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 1  0.080268  0.080268  0.080268  ...  0.080268  0.080268   0.080268
# 2  0.000000  0.000000  0.000000  ...  0.000000  0.000000   0.000000
#
# [3 rows x 149 columns]

# %%
df["modi"]
# Out:
# 0    0.188327
# 1    0.183138
# 2    0.000000
# Name: modi, dtype: float64
